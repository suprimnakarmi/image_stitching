# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img_1 = cv2.resize(cv2.imread("img_1.jpg"),(1024,1024))
img_2=cv2.resize(cv2.imread("img_2.jpg"),(1024,1024))
img_3=cv2.resize(cv2.imread("img_3.jpg"),(1024,1024))

# %%
image_stitcher =cv2.Stitcher.create()

error, stitched_img = image_stitcher.stitch([img_1,img_2,img_3])

# %%
plt.imshow(stitched_img)
